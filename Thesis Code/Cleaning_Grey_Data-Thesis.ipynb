# %%
# Import necessary packages
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. IMPORT FORM DATA

# %%
# Import data
df = pd.read_csv("greyhound_database.csv", encoding = "ISO-8859-1")

# %% [markdown]
# #### View the data

# %%
df.head()
# Out:
#              Name        Date  Track   Dis  Trp  Split Bends  Fin    By  \
# 0  Snowdon Legend  23/04/2016  Pelaw  435m  [2]   5.55  1111  1st   1Â½
# 1  Snowdon Legend  15/04/2016  Pelaw  435m  [3]   5.66  1111  1st   4Â¾
# 2  Snowdon Legend  25/03/2016  Pelaw  435m  [3]   5.62  5455  6th   7Â½
# 3  Snowdon Legend  18/03/2016  Pelaw  435m  [3]   5.64   NaN  NaN   NaN
# 4  Snowdon Legend  10/01/2016  Pelaw  435m  [1]   5.77  4556  6th  10Â¾
#
#             Win/Sec        Remarks   WnTm  Gng  Wght    SP Grade  CalTm
# 0   Ballyroyal Tide  EP,Crd3,Ld3/4  26.33   10  31.0  6/4F    A3  26.43
# 1  Glengiblin Cecil        QAw,ALd  26.75  -40  30.9  5/2C    A3  26.35
# 2          Any Lace       SAw,Crd2  26.07   10  31.5   3/1    A2  26.77
# 3              Solo        Mid-Rls  26.91  -40  31.7   NaN    T1  26.51
# 4       Ardera Buzz         LckdEP  26.30    N  31.6   7/2    A2  27.16

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83172 entries, 0 to 83171
# Data columns (total 17 columns):
# Name       83172 non-null object
# Date       83172 non-null object
# Track      83172 non-null object
# Dis        83172 non-null object
# Trp        83172 non-null object
# Split      78924 non-null float64
# Bends      77711 non-null object
# Fin        79387 non-null object
# By         78853 non-null object
# Win/Sec    83138 non-null object
# Remarks    81886 non-null object
# WnTm       83172 non-null float64
# Gng        83172 non-null object
# Wght       52509 non-null float64
# SP         70214 non-null object
# Grade      83155 non-null object
# CalTm      83172 non-null float64
# dtypes: float64(4), object(13)
# memory usage: 10.8+ MB

# %%
print("COLUMN              DATATYPE       EXAMPLE")
print("----------------------------------------------------------------------")
for col in df.columns:
    print(col," "*(18-len(col)),df[col].dtype," "*(8-len(df[col].dtype)),df.iloc[3940][col])
# Out:
# COLUMN              DATATYPE       EXAMPLE
# ----------------------------------------------------------------------
# Name                object          Tenacious Ben
# Date                object          05/03/2016
# Track               object          Cryfd
# Dis                 object          540m
# Trp                 object          [2]
# Split               float64          13.16
# Bends               object          4333
# Fin                 object          3rd
# By                  object          5Â¾
# Win/Sec             object          Westmead Ellie
# Remarks             object          Chl2-1/2
# WnTm                float64          34.26
# Gng                 object          20
# Wght                float64          32.6
# SP                  object          9/4F
# Grade               object          S4
# CalTm               float64          34.91

# %% [markdown]
# ### 2. DATA CLEANING
# convert string values to numerics where needed, alter certain values, create new columns

# %% [markdown]
# ### Date column to datetime object
# Date stored as standard pandas object, convert to datetime

# %%
df['Date'] = pd.to_datetime(df['Date'].str.strip(), format='%d/%m/%Y')

# %% [markdown]
# ### Delete Non-Runner Records
# Some rows exist for occasions when the greyhound did not run in the race for whatever reason. These will be deleted.

# %%
print("Total No. of records",len(df))
df = df[(df['Fin'] != "NR") & (df['Fin'] != None)]# delete useless rows
print("Total No. of records",len(df))
# Out:
# Total No. of records 83172
# Total No. of records 82652

# %% [markdown]
# #### SOME COLUMNS WERE STORED AS NUMERICAL VALUES AND DID NOT NEED ANY FURTHER WORK
# #### Split
# The time to the first bend, bend_1
# #### WnTm
# The finish time of race winner
# #### CalTm
# Finish time of dog in question
# #### Wght
# weight

# %% [markdown]
# ### Trap
# Almost all UK greyhound races have 6 runners, with traps from 1 to 6. these will be stored as numerics.

# %%
vals=[]
for val in df["Trp"].unique():
    vals.append(val) 
print("Datatype:",df["Trp"].dtype)
print("Values:",vals)
# Out:
# Datatype: object
# Values: ['[2]', '[3]', '[1]', '[4]', '[6]', '[5]', '[]', '[7]', '[8]', '[0]']

# %%
def numerize_trp(field_value):
    try:
        return float("".join(i for i in field_value if i.isdigit()))
    except:
        return None

# %%
df["Trp"] = df["Trp"].apply(numerize_trp) # convert column

# %%
for val in df["Trp"].unique():
    print(val)
# Out:
# 2.0
# 3.0
# 1.0
# 4.0
# 6.0
# 5.0
# nan
# 7.0
# 8.0
# 0.0

# %% [markdown]
# ##### 0 trap?
# Solution to 0 trap = replace with 3.5 (average of 1 to 6)

# %%
df.loc[df['Trp'] == 0]
# Out:
#                   Name       Date   Track   Dis  Trp  Split Bends  Fin   By  \
# 47393   Townsend Rebel 2015-03-09   Derry  274m  0.0    NaN   NaN  1st  NaN
# 50148  Mullrook Wegirl 2015-03-16   Derry  457m  0.0    NaN   NaN  1st  NaN
# 54840  Pennys Mountain 2015-04-24   Clnml  274m  0.0    NaN   NaN  NaN   13
# 75916         So Pearl 2015-10-17  DrumPk  306m  0.0    NaN   NaN  2nd  NaN
#
#             Win/Sec Remarks   WnTm  Gng  Wght   SP Grade  CalTm
# 47393           NaN     NaN  17.34    N   NaN  NaN    GR  17.34
# 50148           NaN     NaN  28.70    N   NaN  NaN    GR  28.70
# 54840          Solo     NaN  16.56    N   NaN  NaN    T1  16.56
# 75916  Santro Flash     NaN  18.49  -15   NaN  NaN    GR   0.00

# %%
for ind, row in df.iterrows(): # replace 0 trap with 3.5, the average of 1 to 6
    val = row["Trp"]
    if val == 0:
        df.at[ind,"Trp"] = 3.5

# %% [markdown]
# ##### 7 and 8 trap?
# only the track "Towc" has races with traps 7 and 8. Only 94 examples. This should not be a problem.

# %%
df.loc[(df['Trp'] == 7) | (df['Trp'] == 8)]
# Out:
#                   Name       Date Track   Dis  Trp  Split Bends  Fin   By  \
# 26953  Farran Williams 2017-01-28  Towc  260m  7.0    NaN  5-7-  7th  7Â¾
# 26954  Farran Williams 2017-01-14  Towc  260m  8.0    NaN  1-7-  8th    7
# 26955  Farran Williams 2017-01-07  Towc  260m  8.0    NaN  7-6-  6th  6Â¼
# 26956  Farran Williams 2016-12-31  Towc  260m  8.0    NaN  2-5-  5th  4Â¼
# 26958  Farran Williams 2016-12-17  Towc  260m  8.0    NaN  1-1-  1st   Â¾
# ...                ...        ...   ...   ...  ...    ...   ...  ...  ...
# 82651    Trapstyle Yam 2017-04-15  Towc  260m  7.0    NaN  5-3-  5th  7Â¼
# 82652    Trapstyle Yam 2017-04-08  Towc  260m  7.0    NaN   NaN  NaN  NaN
# 82656    Trapstyle Yam 2016-12-24  Towc  260m  8.0    NaN  1-2-  3rd  1Â¾
# 82660    Trapstyle Yam 2016-11-12  Towc  260m  7.0    NaN  5-5-  3rd    4
# 82661    Trapstyle Yam 2016-11-05  Towc  260m  8.0    NaN  2-4-  4th    2
#
#                 Win/Sec       Remarks   WnTm  Gng  Wght    SP Grade  CalTm
# 26953    Grafton Willow  SAw,NvrShwd,  16.33  -30  25.4   5/1    D3  16.65
# 26954     Optimus Prime     QAw,EvCh,  16.18  -30  25.2   5/1    D3  16.45
# 26955   Head Iton Sandy       SAw,W2,  16.06  -20  25.4   6/1    D3  16.35
# 26956         Force Ten   EP,W,ClrRn,  15.76  -15  25.2   9/2    D3  15.95
# 26958  Jet Stream Flyer      QAw,ALd,  15.93  -15  25.4   5/1    D3  15.78
# ...                 ...           ...    ...  ...   ...   ...   ...    ...
# 82651       Hack Up Boy           VW2  15.64    N  29.7   8/1    D3  16.23
# 82652           No Race           NaN   0.00    N  30.3   NaN    D3   0.00
# 82656   Near The Bowery     QAw,EvCh,  16.06  -20  30.6   6/1    D3  15.99
# 82660    Chantilly Lass           W2,  15.90  -20  30.7  10/1    D3  16.01
# 82661    Ballymac Misty         W1&2,  15.88  -10  31.1   8/1    D3  15.97
#
# [94 rows x 17 columns]

# %%
vals=[]
for val in df["Trp"].unique():
    vals.append(val) 
print("Datatype:",df["Trp"].dtype)
print("Values:",vals)
# Out:
# Datatype: float64
# Values: [2.0, 3.0, 1.0, 4.0, 6.0, 5.0, nan, 7.0, 8.0, 3.5]

# %% [markdown]
# ### Distance: 'Dis'
# removed the string characters such as 'm' and convert column to numeric.

# %%
vals=[]
for val in df["Dis"].unique():
    vals.append(val)
print("Datatype:",df["Dis"].dtype)
print("Values:",vals)
# Out:
# Datatype: object
# Values: ['435m', '380m', '265m', '480m', '320m', '540m', '380mH', '285m', '450m', '515m', '415m', '592m', '545m', '375m', '714m', '500m', '695m', '274m', '400m', '457m', '297m', '240m', '302m', '329m', '366m', '480mH', '273m', '874m', '225m', '238m', '60mH', '642m', '525m', '462m', '261m', '460m', '277m', '475m', '660m', '555m', '640m', '840m', '718m', '630m', '445m', '503m', '575m', '330m', '280m', '500mH', '515mH', '540mH', '306m', '350m', '335m', '260m', '550m', '300m', '470m', '268m', '263m', '485m', '250m', '305m', '470mH', '275m', '686m', '685m', '290m', '245m', '420m', '620m', '258m', '264m', '428m', '526m', '400mH', '655m', '210m', '750m', '680m', '273mH', '220m', '692m', '700m', '509m', '549m', '768m', '285mH', 'mH', '0m', '659m', '416m', '590m', '668m', '521m', '60m', '265mH', '895m', '736m', '415mH', '663m', '483m', '740m', '764m']

# %%
def numerize_dis(field_value):
    try:
        return float("".join(i for i in field_value if i.isdigit()))
    except:
        #print(field_value)
        return None

# %%
df["Dis"] = df["Dis"].apply(numerize_dis) # convert column

# %%
vals=[]
for val in df["Dis"].unique():
    vals.append(val) 
print("Datatype:",df["Dis"].dtype)
print("Values:",vals)
# Out:
# Datatype: float64
# Values: [435.0, 380.0, 265.0, 480.0, 320.0, 540.0, 285.0, 450.0, 515.0, 415.0, 592.0, 545.0, 375.0, 714.0, 500.0, 695.0, 274.0, 400.0, 457.0, 297.0, 240.0, 302.0, 329.0, 366.0, 273.0, 874.0, 225.0, 238.0, 60.0, 642.0, 525.0, 462.0, 261.0, 460.0, 277.0, 475.0, 660.0, 555.0, 640.0, 840.0, 718.0, 630.0, 445.0, 503.0, 575.0, 330.0, 280.0, 306.0, 350.0, 335.0, 260.0, 550.0, 300.0, 470.0, 268.0, 263.0, 485.0, 250.0, 305.0, 275.0, 686.0, 685.0, 290.0, 245.0, 420.0, 620.0, 258.0, 264.0, 428.0, 526.0, 655.0, 210.0, 750.0, 680.0, 220.0, 692.0, 700.0, 509.0, 549.0, 768.0, nan, 0.0, 659.0, 416.0, 590.0, 668.0, 521.0, 895.0, 736.0, 663.0, 483.0, 740.0, 764.0]

# %% [markdown]
# ### Finish Position: 'Fin'

# %%
vals=[]
for val in df["Fin"].unique():
    vals.append(val) 
print("Datatype:",df["Fin"].dtype)
print("Values:",vals)
# Out:
# Datatype: object
# Values: ['1st', '6th', nan, '2nd', '4th', '3rd', '5th', '7th', '8th', '=2nd', '=3rd']

# %%
def numerize_fin(field_value):
    try:
        return float("".join(i for i in field_value if i.isdigit()))
    except:
        #print(field_value)
        return None

# %%
df["Fin"] = df["Fin"].apply(numerize_fin) # convert column

# %%
vals=[]
for val in df["Fin"].unique():
    vals.append(val) 
print("Datatype:",df["Fin"].dtype)
print("Values:",vals)
# Out:
# Datatype: float64
# Values: [1.0, 6.0, nan, 2.0, 4.0, 3.0, 5.0, 7.0, 8.0]

# %% [markdown]
# ### Distance race won or lost by: 'By'

# %%
vals=[]
for val in df["By"].unique():
    vals.append(val) 
print("Datatype:",df["By"].dtype)
print("Values:",vals)
# Out:
# Datatype: object
# Values: ['1Â½', '4Â¾', '7Â½', nan, '10Â¾', '4', '3Â¾', '10', '5Â¾', 'Â½', '9Â¼', '3Â½', '5Â¼', '2Â¼', '8Â½', 'nk', '6', '8Â¼', '5', '13Â¾', '4Â½', '10Â½', '1Â¾', '12Â¼', '9', '1', '12Â½', '9Â¾', '7Â¼', '6Â½', '16Â¾', '12', '7Â¾', '2Â¾', '6Â¼', 'hd', '3', 'Â¾', '1Â¼', '2', 'shd', '2Â½', '7', '15Â¾', 'dist', '8Â¾', '8', '3Â¼', '11Â¾', '6Â¾', '5Â½', '12Â¾', '4Â¼', '11', '18', '13Â¼', '13', '16Â¼', '14Â¼', '19', '11Â½', '14', '9Â½', '11Â¼', '14Â¾', 'DNF', '13Â½', '22Â½', '15', '17Â¼', '15Â½', '10Â¼', '16Â½', '16', '14Â½', '18Â½', '18Â¾', '17Â¾', '19Â¼', '15Â¼', '19Â½', '25Â¾', '19Â¾', '20', '17', '18Â¼', '20Â¼', '23Â¾', '25Â½', '17Â½', 'dht', '22Â¾', '20Â¾', '22', '48', '21Â¾', '23Â½', '23Â¼', '24', '27', '20Â½', '34Â½', '29Â½', '26Â½', '21Â½', '22Â¼', '43', '21', '24Â½', '21Â¼', '32Â¼', '30Â¾', '35', '24Â¼', '43Â½', '23', '28Â½', '28Â¾', '33Â¼', '33Â½', '26', '29Â¾', '26Â¾', '30', '25']

# %%
def numerize_by(field_value):
    try:
        return float("".join(i for i in field_value if i.isdigit()))
    except:
        #print(field_value)
        return field_value

# %%
df["By"] = df["By"].apply(numerize_by) # convert column

# %%
vals=[]
for val in df["By"].unique():
    vals.append(val) 
print("Datatype:",df["By"].dtype)
print("Values:",vals)
# Out:
# Datatype: object
# Values: [1.0, 4.0, 7.0, nan, 10.0, 3.0, 5.0, 'Â½', 9.0, 2.0, 8.0, 'nk', 6.0, 13.0, 12.0, 16.0, 'hd', 'Â¾', 'shd', 15.0, 'dist', 11.0, 18.0, 14.0, 19.0, 'DNF', 22.0, 17.0, 25.0, 20.0, 23.0, 'dht', 48.0, 21.0, 24.0, 27.0, 34.0, 29.0, 26.0, 43.0, 32.0, 30.0, 35.0, 28.0, 33.0]

# %%
import numbers
for val in vals:
    if isinstance(val, numbers.Number):
        pass
    else:
        print(val)
# Out:
# Â½
# nk
# hd
# Â¾
# shd
# dist
# DNF
# dht

# %%
df.loc[df['By'] == "Â½"] # It appears to be a short distance so will convert to 0.5 for 1/2 metre
# Out:
#                  Name       Date   Track    Dis  Trp  Split Bends  Fin  By  \
# 11     Snowdon Legend 2015-05-28   Cryfd  380.0  2.0   3.81  6332  1.0  Â½
# 45     Snowdon Legend 2014-07-26  Nwbrdg  480.0  3.0   0.95   NaN  2.0  Â½
# 131         Good Fifi 2015-04-07   Cryfd  380.0  6.0   3.68  2111  1.0  Â½
# 305       Clash Tenor 2014-06-13   Cryfd  380.0  5.0   3.70  3222  1.0  Â½
# 318     Wajas Speckle 2016-01-02   Cryfd  380.0  4.0   3.59  1111  1.0  Â½
# ...               ...        ...     ...    ...  ...    ...   ...  ...  ..
# 82973  Winning Jasper 2016-02-20   Cryfd  380.0  5.0   3.57  2111  1.0  Â½
# 82983  Winning Jasper 2015-10-09   Clnml  480.0  5.0    NaN   NaN  1.0  Â½
# 83005    Yahoo Esther 2017-11-09   Cryfd  380.0  1.0   3.49  1111  1.0  Â½
# 83078    Yahoo Esther 2016-04-02   Cryfd  380.0  1.0   3.52  1111  1.0  Â½
# 83083    Yahoo Esther 2016-02-27   Cryfd  380.0  2.0   3.57  2111  1.0  Â½
#
#                 Win/Sec             Remarks   WnTm  Gng  Wght    SP Grade  \
# 11       Lucozade Danni       MsdBrk,LdNrLn  23.90    N  31.3   4/1    A2
# 45        Deanos Legend          Ld1/2,EvCh  29.68    N   NaN  4/7F    A5
# 131       Fairest Belle             EP,SnLd  23.75    N  24.4  EvsF    A6
# 305     Millbrook Dance     Crd1,Bmp&LdNrLn  24.40  -20   NaN   NaN    T3
# 318      Suirview Zippy             QAw,ALd  23.98   20  31.7  7/4F    A6
# ...                 ...                 ...    ...  ...   ...   ...   ...
# 82973   Dromscarra Brae  EP,Disp-Ld3,Bmp1/4  23.73   20  33.3   5/1    A6
# 82983   Slanestown Echo                 NaN  30.09    N  33.2   NaN    T2
# 83005  Actually Blackie             EP,SnLd  23.76   10  26.8   3/1    A3
# 83078     Tonetta Tiger             QAw,ALd  23.43   30  25.3   3/1    A5
# 83083      Avalon Candy              EP,Ld1  23.78   20  25.5  5/4F    A6
#
#        CalTm
# 11     23.90
# 45     29.71
# 131    23.75
# 305    24.20
# 318    24.18
# ...      ...
# 82973  23.93
# 82983  30.09
# 83005  23.86
# 83078  23.73
# 83083  23.98
#
# [1721 rows x 17 columns]

# %%
for ind, row in df.iterrows(): # All are short distances approximately 0.25 metres should work
    val = row["By"]
    if val == 'nk' or val == 'hd' or val == 'shd' or val == 'Â¾':
        df.at[ind,"By"] = 0.25

# %%
for ind, row in df.iterrows(): # 0.5 metres should work
    val = row["By"]
    if val == 'Â½':
        df.at[ind,"By"] = 0.5

# %%
for ind, row in df.iterrows(): # All are long distances DNF=did not finish, dist = a significant distances
    val = row["By"]
    if val == 'DNF' or val == '' or val == 'dist':
        df.at[ind,"By"] = 50.0 # Will replace with 50 metres as this is longest distance recorded in all other examples.

# %%
df.loc[df['By'] == "dht"] # dht, It represents dead heat, that's where 2 or more greyhounds finish joint first
# Out:
#                    Name       Date  Track    Dis  Trp  Split Bends  Fin   By  \
# 5610     Suncroft Rosie 2016-07-12  Sland  450.0  3.0   5.09  1111  1.0  dht
# 6886    Blackrose Linda 2013-07-20  Hnlow  460.0  3.0   3.89  2211  1.0  dht
# 8964   Ballycannon Ruby 2013-11-12  Cryfd  380.0  5.0   3.66  1222  1.0  dht
# 16751     Knockmoy Jack 2016-08-16  Cryfd  380.0  5.0   3.60  4442  1.0  dht
# 17498   Village Blackie 2014-10-04  Cryfd  380.0  5.0   3.62  3322  1.0  dht
# 17601   High St Destiny 2014-10-04  Cryfd  380.0  6.0   3.61  4111  1.0  dht
# 23231     Barrack Bound 2014-05-10  Cryfd  540.0  3.0  13.15  1111  1.0  dht
# 25888   Dromscarra Brae 2017-12-15  Cryfd  540.0  4.0  13.25  2443  1.0  dht
# 26981   Farran Williams 2016-06-17  Cryfd  380.0  6.0   3.54  2111  1.0  dht
# 27466     Frosty Prince 2012-04-07  Sheff  500.0  3.0   4.46  3111  1.0  dht
# 29315          King Pat 2017-01-31  Cryfd  380.0  6.0   3.57  1222  1.0  dht
# 31702     Newcastle Lad 2015-12-19  Cryfd  540.0  3.0  12.86  1111  1.0  dht
# 31743     Newcastle Lad 2014-10-04  Dndlk  320.0  3.0   7.48   NaN  1.0  dht
# 40566    Boots Of Pride 2016-06-17  Cryfd  380.0  4.0   3.57  1222  1.0  dht
# 40972     Chubbys Gooch 2016-06-03  Cryfd  540.0  3.0  13.11  3433  1.0  dht
# 41460          Direwolf 2015-01-29  Hnlow  460.0  5.0   3.90  3322  1.0  dht
# 41680         Fire Line 2014-11-13  Hnlow  460.0  2.0   3.83  4112  1.0  dht
# 41921  Golly Miss Molly 2016-07-19   PerB  480.0  1.0   3.68  4321  1.0  dht
# 43178       Rileys Baby 2014-05-10  Cryfd  540.0  4.0  13.24  4222  1.0  dht
# 43905       Tinas Sarah 2016-11-29  Cryfd  380.0  4.0   3.65  1222  1.0  dht
# 44290       Zenas Bobby 2014-05-24  Cryfd  540.0  4.0  12.90  3111  1.0  dht
# 45484       Cronody Pat 2013-12-27  Cryfd  380.0  2.0   3.88  2222  1.0  dht
# 47806      Besomi Hazel 2013-12-17  Cryfd  380.0  5.0   3.78  3111  1.0  dht
# 48207         Bling Mac 2015-03-20  Sland  450.0  6.0   5.09  5111  1.0  dht
# 48405  Castlebride Maud 2017-06-10  Cryfd  380.0  5.0   3.54  2111  1.0  dht
# 49386       Gosputnicgo 2012-12-20  CPark  480.0  4.0   3.28  5422  1.0  dht
# 51121     Stunning Jojo 2016-11-29  Cryfd  380.0  1.0   3.77  4311  1.0  dht
# 53312      Get On Kenzo 2015-12-19  Cryfd  540.0  1.0  12.98  3222  1.0  dht
# 55704     Stunning Jojo 2016-11-29  Cryfd  380.0  1.0   3.77  4311  1.0  dht
# 58329     Chubbys Gooch 2016-06-03  Cryfd  540.0  3.0  13.11  3433  1.0  dht
# 60006   Farran Williams 2016-06-17  Cryfd  380.0  6.0   3.54  2111  1.0  dht
# 60757      Geneva Danny 2016-08-16  Cryfd  380.0  4.0   3.60  3554  1.0  dht
# 60834      Get On Kenzo 2015-12-19  Cryfd  540.0  1.0  12.98  3222  1.0  dht
# 68379   Tasmanian Devil 2016-10-27  Cryfd  540.0  6.0  13.06  1111  1.0  dht
# 69968   Westmead Clover 2014-03-24  Notts  500.0  3.0   5.19  2222  1.0  dht
# 71224   Blackrose Mable 2015-07-10   Towc  480.0  1.0   4.37  5443  1.0  dht
# 71588  Bling Bling Cara 2017-03-25  Cryfd  380.0  1.0   3.71  2322  1.0  dht
# 71941  Coolavanny Tulsa 2014-10-02  Hnlow  460.0  3.0   3.94  6542  1.0  dht
# 74066          King Pat 2017-01-31  Cryfd  380.0  6.0   3.57  1222  1.0  dht
# 74962       Nellies Jet 2016-12-23  Cryfd  540.0  3.0  13.21  2111  1.0  dht
# 74970       Nellies Jet 2016-10-27  Cryfd  540.0  3.0  13.34  4222  1.0  dht
# 75572  Reenvue Daybreak 2013-12-17  Cryfd  380.0  3.0   3.77  1222  1.0  dht
# 75835       Slanan Siun 2016-06-03  Cryfd  540.0  2.0  13.02  5222  1.0  dht
# 77980       Cronody Pat 2013-12-27  Cryfd  380.0  2.0   3.88  2222  1.0  dht
# 79314     Frosty Prince 2012-04-07  Sheff  500.0  3.0   4.46  3111  1.0  dht
# 81075       Peteles Gem 2016-10-01  Cryfd  380.0  2.0   3.64  2111  1.0  dht
#
#                 Win/Sec               Remarks   WnTm  Gng  Wght    SP Grade  \
# 5610     Russmur Prince                LdRnUp  27.69    N  25.7   6/1    A3
# 6886     Ardera Maureen             Ld3,HldOn  28.92   10   NaN   2/1   A10
# 8964   Millroad Maldini           Bmp1,LdNrLn  24.12    N   NaN   9/2    A5
# 16751      Geneva Danny                 Ld3/4  23.76   10  32.6   5/1    A3
# 17498   High St Destiny   EP,Disp-Bmp1,LdNrLn  23.77   10   NaN   3/1    A3
# 17601   Village Blackie                EP,Ld1  23.77   10   NaN   4/1    A3
# 23231       Rileys Baby               EP,SnLd  34.93   20   NaN   9/4    S7
# 25888    Really O Riley            LdNrLn,Mid  34.25   30  26.1   7/2    S4
# 26981    Boots Of Pride               EP,SnLd  23.57   30  25.4   8/1    A4
# 27466         Jonny Reb                EP,Ld1  30.20   10   NaN  2/1F    A4
# 29315     Droopys Capel  QAw,Ld-1/4,CmAgnNrLn  23.91   10  32.3  3/1J    A7
# 31702      Get On Kenzo                EP,Ld1  34.24   20  32.1   6/1    S4
# 31743        Blue Comet              DH,FnWll  19.24    N   NaN   Evs    S3
# 40566   Farran Williams            Mid,LdNrLn  23.57   30  24.9   6/1    A4
# 40972       Slanan Siun           Crd1,LdNrLn  34.24   20  32.3   4/1    S2
# 41460     Silvus Fulgur                ChlFr3  28.33   20   NaN  2/1F    A9
# 41680   Blackrose Grace           Ld1-3,CmAgn  28.49    N   NaN   3/1    A7
# 41921       Mags Rising        Rls,Crd1,FnWll  29.45    N  26.5  3/1J    A6
# 43178     Barrack Bound    MsdBrk,Crd4,LdNrLn  34.93   20   NaN  6/4F    S7
# 43905     Stunning Jojo   Ld-Crd1/4,CmAgnRnIn  24.24    N  23.4   7/2    A4
# 44290        Noirs Drop                EP,Ld1  34.44    N   NaN   4/1    S2
# 45484      Selkirk Gull        SAw,Crd&LdNrLn  24.66  -20   NaN   NaN    T2
# 47806  Reenvue Daybreak     MsdBrk,EP,Bmp&Ld1  24.63  -40   NaN   NaN    T3
# 48207       Daring Lisa                LdRnUp  28.09   10  31.0   5/2    A6
# 48405    Out Of Chicago             EP,LdRnUp  23.56   20  27.6   9/4    A4
# 49386           Hi Tara      Bmp1,RnOn,LdNrLn  30.16    N   NaN  9/4F    A6
# 51121       Tinas Sarah              Bmp1,Ld2  24.24    N  28.9   7/2    A4
# 53312     Newcastle Lad         Disp-1,LdNrLn  34.24   20  25.3  9/4F    S4
# 55704       Tinas Sarah              Bmp1,Ld2  24.24    N  28.9   7/2    A4
# 58329       Slanan Siun           Crd1,LdNrLn  34.24   20  32.3   4/1    S2
# 60006    Boots Of Pride               EP,SnLd  23.57   30  25.4   8/1    A4
# 60757     Knockmoy Jack                LdNrLn  23.76   10  30.6   4/1    A3
# 60834     Newcastle Lad         Disp-1,LdNrLn  34.24   20  25.3  9/4F    S4
# 68379       Nellies Jet               QAw,ALd  34.61   20  25.8   3/1    S7
# 69968     Mollys Reggie                LdNrLn  30.46   20   NaN   7/2    OR
# 71224      Chuckles Boy            Bmp3/4,Ld4  29.60   10  27.2   7/1    A8
# 71588    Hollyhill Lola                LdRnIn  24.41   10  27.7   6/1    A8
# 71941    Coolruss Delta       SAw,Crd1,FnVStr  28.22   10   NaN  EvsF    A7
# 74066     Droopys Capel  QAw,Ld-1/4,CmAgnNrLn  23.91   10  32.3  3/1J    A7
# 74962     Kingdom Fancy                EP,Ld1  34.59   30  25.6   5/1    S7
# 74970   Tasmanian Devil         2ndFr2-LdNrLn  34.61   20  25.3   6/1    S7
# 75572      Besomi Hazel  Disp-Crd1,LdNrLn,Mid  24.63  -40   NaN   NaN    T3
# 75835     Chubbys Gooch          MsdBrk,Ld3/4  34.24   20  27.7   9/2    S2
# 77980      Selkirk Gull        SAw,Crd&LdNrLn  24.66  -20   NaN   NaN    T2
# 79314         Jonny Reb                EP,Ld1  30.20   10   NaN  2/1F    A4
# 81075   Mercury Pegasus    EP,Chl&Bmp1,ChlFr2  24.07   10  24.2   4/1    A8
#
#        CalTm
# 5610   27.69
# 6886   29.02
# 8964   24.12
# 16751  23.86
# 17498  23.87
# 17601  23.87
# 23231  35.13
# 25888  34.55
# 26981  23.87
# 27466  30.30
# 29315  24.01
# 31702  34.44
# 31743  19.24
# 40566  23.87
# 40972  34.44
# 41460  28.53
# 41680  28.49
# 41921  29.45
# 43178  35.13
# 43905  24.24
# 44290  34.44
# 45484  24.46
# 47806  24.23
# 48207  28.19
# 48405  23.76
# 49386  30.16
# 51121  24.24
# 53312  34.44
# 55704  24.24
# 58329  34.44
# 60006  23.87
# 60757  23.86
# 60834  34.44
# 68379  34.81
# 69968  30.66
# 71224  29.70
# 71588  24.51
# 71941  28.32
# 74066  24.01
# 74962  34.89
# 74970  34.81
# 75572  24.23
# 75835  34.44
# 77980  24.46
# 79314  30.30
# 81075  24.17

# %%
for ind, row in df.iterrows(): # 0 metres is used for dht (dead heat)
    val = row["By"]
    if val == 'dht':
        df.at[ind,"By"] = 0.0

# %%
df["By"] = pd.to_numeric(df["By"]) # Column was not auto converted so conversion required

# %%
vals=[]
for val in df["By"].unique():
    vals.append(val) 
print("Datatype:",df["By"].dtype)
print("Values:",vals)
# Out:
# Datatype: float64
# Values: [1.0, 4.0, 7.0, nan, 10.0, 3.0, 5.0, 0.5, 9.0, 2.0, 8.0, 0.25, 6.0, 13.0, 12.0, 16.0, 15.0, 50.0, 11.0, 18.0, 14.0, 19.0, 22.0, 17.0, 25.0, 20.0, 23.0, 0.0, 48.0, 21.0, 24.0, 27.0, 34.0, 29.0, 26.0, 43.0, 32.0, 30.0, 35.0, 28.0, 33.0]

# %%
for ind, row in df.iterrows(): # 0 metres is used for dht (dead heat)
    finished = row["Fin"]
    by = row["By"]
    if finished > 1:
        df.at[ind,"By"] = by*-1

# %%
vals=[]
for val in df["By"].unique():
    vals.append(val) 
print("Datatype:",df["By"].dtype)
print("Values:",vals)
# Out:
# Datatype: float64
# Values: [1.0, 4.0, -7.0, nan, -10.0, -4.0, -3.0, -5.0, 0.5, -9.0, -2.0, -8.0, 0.25, -6.0, -13.0, -12.0, 2.0, 7.0, 6.0, -0.5, -16.0, 12.0, -1.0, 3.0, 15.0, -50.0, -11.0, -0.25, 13.0, -18.0, 5.0, -14.0, -19.0, 8.0, -22.0, -15.0, -17.0, 9.0, 50.0, 10.0, 18.0, 25.0, -20.0, 11.0, -23.0, -25.0, 0.0, 20.0, 19.0, 14.0, -48.0, 17.0, 21.0, 16.0, 23.0, -21.0, -24.0, 27.0, -34.0, -29.0, -26.0, 43.0, 22.0, -32.0, 30.0, -35.0, -43.0, -28.0, -33.0, 33.0, -27.0, -30.0, 24.0]

# %% [markdown]
# #### Bends

# %%
vals=[]
for val in df["Bends"].unique():
    vals.append(val) 
print("Datatype:",df["Bends"].dtype)
print("Values:",vals)
# Out:
# Datatype: object
# Values: ['1111', '5455', nan, '4556', '2222', '5444', '4566', '4444', '6444', '6332', '4466', '4433', '6355', '4223', '2111', '3666', '3444', '3344', '2333', '5555', '3555', '5-4-', '4325', '5666', '1112', '4225', '5344', '6533', '4555', '3334', '2223', '1122', '2146', '6555', '4312', '1333', '5554', '6333', '6644', '6544', '4544', '4222', '3533', '3544', '3333', '4322', '3554', '5443', '5111', '4543', '2211', '2544', '4321', '6566', '2655', '4333', '1555', '4434', '3534', '1655', '4332', '1222', '3543', '3111', '1334', '2555', '3311', '2443', '2666', '3443', '3211', '3656', '5655', '3422', '3665', '4666', '6656', '3222', '5333', '1434', '3322', '3326', '4554', '1211', '6543', '5466', '1566', '1313', '2335', '2444', '2322', '5432', '2433', '3655', '2665', '5645', '1454', '6666', '2224', '3345', '2566', '3221', '4655', '3335', '5545', '1232', '5544', '2332', '2345', '2455', '6665', '4533', '3456', '5334', '1444', '2334', '4455', '2112', '6554', '5664', '4233', '5433', '4443', '2221', '4111', '6443', '5665', '3355', '2143', '1556', '3324', '4656', '3565', '1124', '3442', '1123', '2344', '1121', '3556', '6545', '4354', '5322', '4221', '6445', '3332', '6222', '6433', '2556', '5211', '1212', '3223', '5446', '2445', '4353', '3343', '5535', '6111', '4345', '4334', '1-1-', '1233', '1223', '5222', '5233', '2122', '2233', '5565', '6565', '3563', '6553', '5445', '5431', '6322', '4151', '3212', '4445', '1244', '3553', '1344', '2232', '3455', '1125', '1243', '5556', '5454', '6233', '5235', '1234', '3454', '6345', '1146', '2442', '4344', '3433', '1343', '3232', '2454', '1666', '1456', '3566', '3445', '3342', '5465', '6655', '5456', '2355', '3224', '5332', '5422', '1134', '1455', '4545', '1235', '3323', '2644', '6531', '3434', '5323', '3421', '2343', '1332', '1554', '4644', '6654', '1221', '5644', '3112', '2645', '1543', '4423', '4633', '1345', '555', '3331', '3213', '1443', '3632', '1466', '5225', '6334', '6466', '5434', '2212', '5533', '4112', '5122', '6434', '6422', '4211', '5423', '2321', '1422', '1132', '6-6-', '6556', '1322', '2532', '2453', '3532', '5654', '1224', '2564', '2456', '4432', '4665', '2244', '1133', '5566', '4664', '6455', '3466', '5223', '4551', '5354', '6123', '5543', '4663', '1644', '6442', '3446', '3124', '3122', '2234', '3233', '3244', '5345', '3144', '2356', '1115', '6456', '3234', '4335', '6633', '2543', '4553', '6522', '5656', '6534', '6343', '5312', '43560', '1145', '1464', '3321', '2346', '3125', '6653', '4-5-', '43527', '43499', '43589', '43622', '6563', '3644', '4331', '2432', '4442', '5321', '4465', '2423', '1445', '6211', '3366', '2552', '1266', '2133', '4565', '3266', '3123', '5342', '2123', '3545', '5256', '2235', '1665', '6645', '4114', '4311', '5366', '4232', '6344', '4235', '6632', '4-6-', '3133', '4355', '4323', '6336', '4654', '6664', '1656', '2134', '2121', '5355', '2113', '5221', '2265', '3135', '6454', '4144', '6643', '2245', '1323', '3236', '1342', '5421', '2313', '4454', '2554', '1355', '4446', '6535', '2446', '4453', '2135', '5336', '3134', '4122', '4124', '1143', '1113', '2216', '1114', '4244', '2366', '4532', '5453', '2323', '2434', '1311', '4212', '3225', '3166', '2256', '1144', '2243', '3243', '4422', '1154', '1142', '6244', '6255', '5324', '1433', '1166', '2124', '3126', '2266', '5245', '4234', '5356', '2653', '4441', '6432', '1356', '6552', '3465', '1544', '4214', '1335', '4523', '2225', '1245', '1411', '3356', '1242', '2565', '2422', '2115', '2324', '4366', '5553', '6232', '6542', '6646', '5335', '5522', '5311', '4224', '4255', '6421', '6331', '6465', '6224', '4266', '2533', '3255', '4456', '2125', '4226', '3-5-', '1-2-', '2466', '1135', '2255', '2311', '1321', '6532', '665', '6446', '2342', '5214', '5-5-', '5112', '5146', '3066', '4245', '4133', '6663', '6453', '4563', '2312', '1354', '1255', '3564', '2-2-', '3-6-', '3336', '6356', '4346', '3121', '6231', '5622', '6223', '5365', '3145', '4303', '4145', '5534', '2534', '5532', '6323', '1366', '6321', '2331', '6312', '4564', '3226', '2354', ...

# %%
def numerize_bends(field_value): # first convert each to numbers
    try:
        return float("".join(int(i) for i in field_value if i.isdigit()))
    except:
        return field_value

# %%
df["Bends"] = df["Bends"].apply(numerize_bends) # convert column

# %%
# Get bends seperately
def bend_1(field_value): 
    try:
        return int(str(field_value)[0])
    except:
        return None
    
def bend_2(field_value): 
    try:
        return int(str(field_value)[1])
    except:
        return None

def bend_3(field_value): 
    try:
        return int(str(field_value)[2])
    except:
        return None
    
def bend_4(field_value): 
    try:
        return int(str(field_value)[3])
    except:
        return None

# %%
df["Bend_1"] = df["Bends"].apply(bend_1) # new column
df["Bend_2"] = df["Bends"].apply(bend_2) # new column
df["Bend_3"] = df["Bends"].apply(bend_3) # new column
df["Bend_4"] = df["Bends"].apply(bend_4) # new column

# %%
df["Bend_1"] = pd.to_numeric(df["Bend_1"]) # Column was not auto converted so conversion required
df["Bend_2"] = pd.to_numeric(df["Bend_2"]) # Column was not auto converted so conversion required
df["Bend_3"] = pd.to_numeric(df["Bend_3"]) # Column was not auto converted so conversion required
df["Bend_4"] = pd.to_numeric(df["Bend_4"]) # Column was not auto converted so conversion required

# %%
df = df.drop(columns=["Bends"]) # Bends can now be dropped

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82652 entries, 0 to 83171
# Data columns (total 20 columns):
# Name       82652 non-null object
# Date       82652 non-null datetime64[ns]
# Track      82652 non-null object
# Dis        82651 non-null float64
# Trp        82638 non-null float64
# Split      78924 non-null float64
# Fin        78867 non-null float64
# By         78853 non-null float64
# Win/Sec    82618 non-null object
# Remarks    81550 non-null object
# WnTm       82652 non-null float64
# Gng        82652 non-null object
# Wght       52509 non-null float64
# SP         70214 non-null object
# Grade      82635 non-null object
# CalTm      82652 non-null float64
# Bend_1     77711 non-null float64
# Bend_2     75980 non-null float64
# Bend_3     77709 non-null float64
# Bend_4     75964 non-null float64
# dtypes: datetime64[ns](1), float64(12), object(7)
# memory usage: 15.7+ MB

# %% [markdown]
# #### Racing Post SP (Starting Price (Odds))

# %%
vals=[]
for val in df["SP"].unique():
    vals.append(val) 
print("Datatype:",df["SP"].dtype)
print("Values:",vals)
# Out:
# Datatype: object
# Values: ['6/4F', '5/2C', '3/1', nan, '7/2', '12/1', '6/1', '4/1', '20/1', '16/1', '8/1', '5/1', '9/2', '5/2', '14/1', '3/1C', '10/1', '2/1F', '9/4F', '7/4F', '4/7F', '2/1C', '2/1', '4/5F', '7/1', '5/2F', '2/1J', '5/2J', 'EvsF', '3/1J', '5/4F', '9/4', '9/4J', '3/1F', '7/2C', '11/4', '6/4', '5/4J', '6/4J', '7/4J', '25/1', '11/4J', 'Evs', '7/4', '10/11F', '11/8F', '11/4F', '40/1', '11/10F', '66/1', '50/1', '4/5', '4/6F', '8/13F', '5/4', '33/1', '4/1F', '11/4C', '9/4C', '7/2J', '4/1C', '11/2', '6/4C', '8/11F', '7/2F', '13/8F', '1/2F', '11/8J', '15/8F', '2/5F', '4/6', '2/5', '11/10', '5/1F', '1/1', '9/1', '4/9F', '11/1', '13/1', '15/2', '100/30', '13/2', '7/4C', '13/8', 'N/O', '100/1', '125/1', '1/2', '4/7', '17/2', 'N/P', 'EvsJ']

# %%
def numerize_sp(field_value): # Create Decimal Odds from the fractional odds stored as strings e.g. 2/1 or Evs
    try:
        return round(float(field_value),2)
    except:
        try:
            split_data = field_value.split("/") # Fractionals such as 2/1, 4/1, 5/2
            numer = float("".join(i for i in split_data[0] if i.isdigit()))
            denom = float("".join(i for i in split_data[1] if i.isdigit()))
            return round((numer/denom)+1,2)
        except:
            if 'Evs' in field_value: # For all types of evens odds (50/50)
                return 2.0
            return None

# %%
df["SP"] = df["SP"].apply(numerize_sp) # convert column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82652 entries, 0 to 83171
# Data columns (total 20 columns):
# Name       82652 non-null object
# Date       82652 non-null datetime64[ns]
# Track      82652 non-null object
# Dis        82651 non-null float64
# Trp        82638 non-null float64
# Split      78924 non-null float64
# Fin        78867 non-null float64
# By         78853 non-null float64
# Win/Sec    82618 non-null object
# Remarks    81550 non-null object
# WnTm       82652 non-null float64
# Gng        82652 non-null object
# Wght       52509 non-null float64
# SP         70210 non-null float64
# Grade      82635 non-null object
# CalTm      82652 non-null float64
# Bend_1     77711 non-null float64
# Bend_2     75980 non-null float64
# Bend_3     77709 non-null float64
# Bend_4     75964 non-null float64
# dtypes: datetime64[ns](1), float64(13), object(6)
# memory usage: 15.7+ MB

# %% [markdown]
# #### Race Grade

# %%
vals=[]
for val in df["Grade"].unique():
    vals.append(val) 
print("Datatype:",df["Grade"].dtype)
print("Values:",vals)
# Out:
# Datatype: object
# Values: ['A3', 'A2', 'T1', 'T3', 'A1', 'OR', 'A4', 'A5', 'N1', 'T2', 'A6', 'A7', 'S6', 'A8', 'H3', 'S7', 'S5', 'S4', 'IT', 'GR', 'S3', 'S2', 'T4', 'S1', 'IV', 'S8', 'P3', 'P1', 'N2', 'P2', 'H2', 'H1', 'N3', 'E3', 'M1', 'E2', 'H4', 'D3', 'D2', 'A10', 'HP', 'E1', 'A9', 'A11', 'D4', 'D1', 'B6', 'B5', 'B4', 'B1', 'B2', 'B3', 'KS', 'S9', nan, 'HS1', 'M3', 'P5', 'H0', 'HD1', 'P7', 'P4', 'B7', 'B8', 'S10', 'T5', 'D5']

# %%
grades = ["A1","A2","A3","A4","A5","A6","A7","A8","A9","A10","A11"]
def grade_A_numeric(field_value):# Used to give numeric value(in new column) for A grade races 1 to 11
    try:
        if "A" in field_value:
            num = float("".join(i for i in field_value if i.isdigit()))
            return num
        else:
            return None
    except:
        None

# %%
df["Grade_A_Numeric"] = df["Grade"].apply(grade_A_numeric)

# %%
vals=[]
for val in df["Grade_A_Numeric"].unique():
    vals.append(val) 
print("Datatype:",df["Grade_A_Numeric"].dtype)
print("Values:",vals)
# Out:
# Datatype: float64
# Values: [3.0, 2.0, nan, 1.0, 4.0, 5.0, 6.0, 7.0, 8.0, 10.0, 9.0, 11.0]

# %% [markdown]
# #### Going (Ground/Weather Conditions): Gng

# %%
vals=[]
for val in df["Gng"].unique():
    vals.append(val) 
print("Datatype:",df["Gng"].dtype)
print("Values:",vals)
# Out:
# Datatype: object
# Values: ['10', '-40', 'N', '-20', '20', '-10', '30', '-30', '50', '-25', '-50', '15', '40', '-35', '-15', '-80', '-45', '-60', '-5', '-70', '60', '-160', '-100', '-90', '5', '-140', '70', '-150', '-120', '80', '-130', '25', '90', '-110', '-180', '-190', '-220', '35', '-75', '-55', '-170', '-105', '100']

# %%
def numerize_going(field_value): # first convert each to numbers
    try:
        return round(float(field_value),2)
    except:
        try:
            return float("".join(int(i) for i in field_value if i.isdigit()))
        except:
            if field_value == "N":
                return 0.0

# %%
df["Gng"] = df["Gng"].apply(numerize_going)

# %%
vals=[]
for val in df["Gng"].unique():
    vals.append(val) 
print("Datatype:",df["Gng"].dtype)
print("Values:",vals)
# Out:
# Datatype: float64
# Values: [10.0, -40.0, 0.0, -20.0, 20.0, -10.0, 30.0, -30.0, 50.0, -25.0, -50.0, 15.0, 40.0, -35.0, -15.0, -80.0, -45.0, -60.0, -5.0, -70.0, 60.0, -160.0, -100.0, -90.0, 5.0, -140.0, 70.0, -150.0, -120.0, 80.0, -130.0, 25.0, 90.0, -110.0, -180.0, -190.0, -220.0, 35.0, -75.0, -55.0, -170.0, -105.0, 100.0]

# %% [markdown]
# #### New column: Num_Opps
# The expected no. of competitors in a race (some will have nr unfortunately)

# %%
def num_opps(field_value): # This will give the expected number of opponents, generally 6 except for trials
    try:
        if field_value[0] == "T":
            num = float("".join(i for i in field_value if i.isdigit()))
            return num
        else:
            return 6
    except:
        return 6

# %%
df["Num_Opps"] = df["Grade"].apply(num_opps)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82652 entries, 0 to 83171
# Data columns (total 22 columns):
# Name               82652 non-null object
# Date               82652 non-null datetime64[ns]
# Track              82652 non-null object
# Dis                82651 non-null float64
# Trp                82638 non-null float64
# Split              78924 non-null float64
# Fin                78867 non-null float64
# By                 78853 non-null float64
# Win/Sec            82618 non-null object
# Remarks            81550 non-null object
# WnTm               82652 non-null float64
# Gng                82652 non-null float64
# Wght               52509 non-null float64
# SP                 70210 non-null float64
# Grade              82635 non-null object
# CalTm              82652 non-null float64
# Bend_1             77711 non-null float64
# Bend_2             75980 non-null float64
# Bend_3             77709 non-null float64
# Bend_4             75964 non-null float64
# Grade_A_Numeric    53651 non-null float64
# Num_Opps           82652 non-null float64
# dtypes: datetime64[ns](1), float64(16), object(5)
# memory usage: 17.0+ MB

# %% [markdown]
# #### Remarks
# These are the comments section, which describe a greyhounds race

# %%
vals=[]
for val in df["Remarks"].unique():
    vals.append(val) 
print("Datatype:",df["Remarks"].dtype)
print("Values:",vals)
# Out:
# Datatype: object
# Values: ['EP,Crd3,Ld3/4', 'QAw,ALd', 'SAw,Crd2', 'Mid-Rls', 'LckdEP', 'Rls-Mid,ClrRn', 'Mid,ClrRn', 'Bmp1,Crd4', 'Crd1&2&3', 'Bmp1/4&3&4', 'Crd1/4&2', 'MsdBrk,LdNrLn', 'BmpRnUp&1,Crd2&3', 'Crd1Rls', 'CrdRnUp&1/4', 'RnOn', 'Crd1', 'EP,SnLd', 'Crd1&2', 'Crd1/4', 'EP,Crd1&1/4&1/2', 'EvCh,Rls', 'MsdBrk,Crd1&2', 'Bmp1/4', 'CrdRnUp', 'BdCrd1', 'Crd1/4&2&3', 'BmpRnUp,Mid-Rls', 'MsdBrk,Bmp1/4,Crd3', 'EP,2ndFr1,Chl1/4', 'EP,Ld1/4-Bmp3', 'EP,Bmp1,Chl&Bmp3', 'BdCrd&W1/4', 'MsdBrk,Bmp1/4&3', 'MsdBrk,Crd3', 'BmpStt,Chl&Crd1/4,Crd2', 'BmpStt,Crd2,HitRls3', 'EP,Ld1', 'Ld1/4,Mid-Rls', 'EP,LdRnUp,Mid-Rls', 'Ld1/2,EvCh', 'Imp1,NvrShwd', 'QAw,RlsRnUp', 'QAw,EvCh', 'QAw,Fcd-Ck3', 'EvAw,A2nd', nan, 'Crd1&1/4,(ReQul)', 'MsdBrk,Crd1', 'Crd1,Ld2-Bmp3', 'EP,Disp-Crd1/4', 'EP,Ld1/4,Mid', 'BmpStt&2,Crd1/2', 'Crd1,RnOn', 'CrdStt,Bmp2,RnOn', 'Bmp1,Blk1/4', 'SAw,Crd3&4', 'MsdBrk,RnOn', 'BmpStt,LdNrLn', 'Bmp1/4,Crd4', 'Crd&W1/4', 'Bmp1,Crd1/4', 'EP,2ndFr1-1/4', 'EP,Crd&Ld1/4', '2ndFr1/4', 'Bmp1&1/4', 'Mid', 'Mid,RnOn', 'Crd1&1/2', 'EP,SnLd,Mid', 'MsdBrk,Ld1/4', 'MsdBrk', 'Crd1,Bmp3/4', 'EP,Crd1/4,Ld2', 'Ld3,Mid', 'SAw,Crd&Fell2', 'MsdBrk,Crd1/4', 'BdCrd1/4,Crd2', 'MsdBrk,CrdRnUp,RnOn', 'EvCh,Mid', 'BmpStt&RnUp,Crd3&3/4', 'Crd3,RnOn', 'EvCh', 'Crd1/2,Chl4-RnIn', 'Bmp1,Crd&W4', 'EP,2ndFr1', 'Bmp1&1/4,RnOn', 'EP,Ld1/4', 'BdCrd1/4-2', 'EP,BmpRnUp,Disp-Bmp1/4', 'Crd1/4,Mid', 'EP,Ld2', 'Crd1/4&3', 'BmpRnUp,BdCrd1/4', 'MsdBrk,Bmp1&1/4', 'BmpStt&2,RnOn', 'Disp-Blk1,KO1/4', 'Mid-W,Ld1/2', 'Crd3,Mid-W', 'BmpRnUp,Crd1/2&4', 'Mid-W', 'CrdRnUp,BdCrd&Fell1/4', 'CrdRnUp,RnOn', 'MsdBrk,EP,Ld2', 'Crd1/4&3/4', 'EP,SnLd,Mid-W', 'BmpRnUp,Crd1/4', 'Crd2', 'MsdBrk,BdCrd1/4', 'Blk1/4,2ndFr2', 'BmpRnUp,Crd1/4,RnOn', 'BdCrdRnUp,Crd1/4', 'Crd1/4,RnOn', 'EP,SnLd-Bmp1/4', 'Crd&BdDistracted1/2(ReQul)', 'MsdBrk,Crd1/4&3&4', 'Crd4,RnOn', 'Bmp1&4&RnIn', 'Crd1&1/2&3&3/4', 'EP,Crd1&1/4,Bmp3', 'BmpRnUp,Crd2,RnOn', 'CrdRnUp&1&1/2', 'BdCrd1/4', 'Bmp1/4&3,2ndFr3/4', 'Bmp1,RnOn', 'EP,Chl&Crd1/4,Bmp3', 'Crd1&3/4,BdCrd1/4', 'EP,2ndFr2', 'BdCrd1/2,Crd3', 'MsdBrk,Bmp1/4,Crd3,RnOn', 'Crd1/4&1/2,Bmp3', 'Crd3,LdRnIn', 'Crd1&4', 'CrdRnUp&1/4&3,Bmp1', 'MsdBrk,Crd1/4,Bmp3', 'ALd,Mid-W', 'MsdBrk,Stmb&BdCrd2', 'CrdRnUp&1/4,Ckd&StoppedSough', 'EP,LdRnUp,Mid', 'EP,LdRnUp,Mid-W', 'Disp-1,Ld2-1/2', 'Crd1/2,W', 'W1/4,2ndFr4', 'EP,SnLd-RnIn', 'EP,2ndFr2-Ld3/4', 'MsdBrk,2ndFr1/2,RnOn', 'Crd1/2,Mid-W', 'MsdBrk,W', 'W,RnOn', 'MsdBrk,CrdRnUp&4', 'Bmp1&1/4,2ndFr2', 'Bmp1/4,W', 'EvCh,Mid-W', 'EP,Ld3,W', 'EP,LdRnUp', 'MsdBrk,Crd1/2,Bmp3', 'Crd1/4&2&1/2', 'Bmp1,BdCrd1/4,Crd4', 'W1/4', 'EP,Disp-Blk1/4', 'BmpRnUp,Crd1/4&3', 'Bmp1/4,2ndFr2,RnOn', 'EP,2ndFr1-4', 'Crd1/4,Mid-W', 'Bmp1,Crd1/4&3/4', 'LeftStt', 'EP,Disp-1/4', 'Bmp&Ld1/4', 'WStt', 'MsdBrk,Blk1,(ReQul)', '2ndFr1/4-1/2,Crd3', 'EP,Ld3', 'Crd&W1/4,Crd2', 'RnOn,Mid-W', 'LdRnIn', 'W,Crd1/2', 'EP,Disp-Bmp1/4,Crd3/4', 'EP,SnLd-1/4', 'WRnUp,Crd1/4', 'MsdBrk,Crd2,Bmp3', 'W', 'CghtMuzzle,Stt', 'EP,SnLd-W1/4,CmAgn', 'Crd3/4,RnOn', 'W,EvCh', 'MsdBrk,BmpStt&3', 'Bmp1/4,2ndFr2-4', 'Crd1&3/4', 'Crd1&1/4', 'Bmp1/4,Crd3', 'EP,Disp-Ld1/4', 'Disp-Bmp1,RnOn', 'BmpStt,Crd1/4&3', 'SAw,Blk1/4', 'Crd1/2&3', 'EP,Ld1,Mid-W', 'MsdBrk,Bmp1,RnOn', 'BmpStt&1,Crd1/2', 'Crd1&2&1/2&3', 'EP,SnLd,Bmp1/4', 'EP,Disp-Bmp1/4', 'CrdStt&2', 'EP,Ld3/4', 'BmpRnUp&1,Crd1/4&1/2&3', 'Crd1&3', 'Bmp1/4,2ndFr2', 'Bmp1&1/4,Crd3', 'Bmp1,Crd3', 'EP,SnLd-3,Bmp1/4', 'MsdBrk,EP,Crd1', 'StmbStt,Crd1/4', 'EP,SnLd-Bmp1,Bmp1/4&3', 'EP,Disp-Crd1/4,Crd3&RnIn', 'MsdBrk,EP,Crd3', 'MsdBrk,EP,Crd1/4&2', 'Disp-1,Ld3', 'BmpRnUp,Crd1&2', 'MsdBrk,EP,Bmp1,Crd3', 'Chl&Crd1/4,Crd2&3', 'MsdBrk,BdCrd1,Crd3', 'MsdBrk,Bmp1/4,ChlFr4', 'MsdBrk,Crd&W1/4,Crd3', 'Crd1,Bmp&LdNrLn', 'EP,SnLd-NrLn,Mid', 'EP,Fdd,RnIn', 'EP,Imp4', 'BmpStt&1H,Hit2H', 'BmpStt,Crd2H&1/4,Hit3H', 'Mid&Crd1/4,Crd3H', 'JmpEarly&Hit1H,Rls', 'RlsRnUp,Hit1H&Fell', 'QAw,ALd,MidRnUp', 'Rls,Hit&Stmb3H', 'QAw,ALd,Mid', 'SnLd-1/2,Ckd3&5,(ReQul)', 'QAw,Hit1H,Rls', 'Crd&W1', 'JmpWll,Rls', 'MsdBrk,CrdRnUp', 'EP,SnLd-4', 'Disp-Crd1,2ndFr1/2-NrLn', '2ndFr4', 'BdCrd5', 'EP,SnLd-2,Bmp2/ ...

# %%
print("No. of different remarks/comments = ",len(set(vals)))
# Out:
# No. of different remarks/comments =  19810

# %% [markdown]
# #### Reduce No. Unique Remarks

# %%
new_vals = [] # Split Each comment type by comma(,) and get set of unique comments
for v in vals:
    try:
        y = v.replace('-',',').split(",")
        new_vals.extend(y)
    except:
        new_vals.append(v)

# %%
print(new_vals)
# Out:
# ['EP', 'Crd3', 'Ld3/4', 'QAw', 'ALd', 'SAw', 'Crd2', 'Mid', 'Rls', 'LckdEP', 'Rls', 'Mid', 'ClrRn', 'Mid', 'ClrRn', 'Bmp1', 'Crd4', 'Crd1&2&3', 'Bmp1/4&3&4', 'Crd1/4&2', 'MsdBrk', 'LdNrLn', 'BmpRnUp&1', 'Crd2&3', 'Crd1Rls', 'CrdRnUp&1/4', 'RnOn', 'Crd1', 'EP', 'SnLd', 'Crd1&2', 'Crd1/4', 'EP', 'Crd1&1/4&1/2', 'EvCh', 'Rls', 'MsdBrk', 'Crd1&2', 'Bmp1/4', 'CrdRnUp', 'BdCrd1', 'Crd1/4&2&3', 'BmpRnUp', 'Mid', 'Rls', 'MsdBrk', 'Bmp1/4', 'Crd3', 'EP', '2ndFr1', 'Chl1/4', 'EP', 'Ld1/4', 'Bmp3', 'EP', 'Bmp1', 'Chl&Bmp3', 'BdCrd&W1/4', 'MsdBrk', 'Bmp1/4&3', 'MsdBrk', 'Crd3', 'BmpStt', 'Chl&Crd1/4', 'Crd2', 'BmpStt', 'Crd2', 'HitRls3', 'EP', 'Ld1', 'Ld1/4', 'Mid', 'Rls', 'EP', 'LdRnUp', 'Mid', 'Rls', 'Ld1/2', 'EvCh', 'Imp1', 'NvrShwd', 'QAw', 'RlsRnUp', 'QAw', 'EvCh', 'QAw', 'Fcd', 'Ck3', 'EvAw', 'A2nd', nan, 'Crd1&1/4', '(ReQul)', 'MsdBrk', 'Crd1', 'Crd1', 'Ld2', 'Bmp3', 'EP', 'Disp', 'Crd1/4', 'EP', 'Ld1/4', 'Mid', 'BmpStt&2', 'Crd1/2', 'Crd1', 'RnOn', 'CrdStt', 'Bmp2', 'RnOn', 'Bmp1', 'Blk1/4', 'SAw', 'Crd3&4', 'MsdBrk', 'RnOn', 'BmpStt', 'LdNrLn', 'Bmp1/4', 'Crd4', 'Crd&W1/4', 'Bmp1', 'Crd1/4', 'EP', '2ndFr1', '1/4', 'EP', 'Crd&Ld1/4', '2ndFr1/4', 'Bmp1&1/4', 'Mid', 'Mid', 'RnOn', 'Crd1&1/2', 'EP', 'SnLd', 'Mid', 'MsdBrk', 'Ld1/4', 'MsdBrk', 'Crd1', 'Bmp3/4', 'EP', 'Crd1/4', 'Ld2', 'Ld3', 'Mid', 'SAw', 'Crd&Fell2', 'MsdBrk', 'Crd1/4', 'BdCrd1/4', 'Crd2', 'MsdBrk', 'CrdRnUp', 'RnOn', 'EvCh', 'Mid', 'BmpStt&RnUp', 'Crd3&3/4', 'Crd3', 'RnOn', 'EvCh', 'Crd1/2', 'Chl4', 'RnIn', 'Bmp1', 'Crd&W4', 'EP', '2ndFr1', 'Bmp1&1/4', 'RnOn', 'EP', 'Ld1/4', 'BdCrd1/4', '2', 'EP', 'BmpRnUp', 'Disp', 'Bmp1/4', 'Crd1/4', 'Mid', 'EP', 'Ld2', 'Crd1/4&3', 'BmpRnUp', 'BdCrd1/4', 'MsdBrk', 'Bmp1&1/4', 'BmpStt&2', 'RnOn', 'Disp', 'Blk1', 'KO1/4', 'Mid', 'W', 'Ld1/2', 'Crd3', 'Mid', 'W', 'BmpRnUp', 'Crd1/2&4', 'Mid', 'W', 'CrdRnUp', 'BdCrd&Fell1/4', 'CrdRnUp', 'RnOn', 'MsdBrk', 'EP', 'Ld2', 'Crd1/4&3/4', 'EP', 'SnLd', 'Mid', 'W', 'BmpRnUp', 'Crd1/4', 'Crd2', 'MsdBrk', 'BdCrd1/4', 'Blk1/4', '2ndFr2', 'BmpRnUp', 'Crd1/4', 'RnOn', 'BdCrdRnUp', 'Crd1/4', 'Crd1/4', 'RnOn', 'EP', 'SnLd', 'Bmp1/4', 'Crd&BdDistracted1/2(ReQul)', 'MsdBrk', 'Crd1/4&3&4', 'Crd4', 'RnOn', 'Bmp1&4&RnIn', 'Crd1&1/2&3&3/4', 'EP', 'Crd1&1/4', 'Bmp3', 'BmpRnUp', 'Crd2', 'RnOn', 'CrdRnUp&1&1/2', 'BdCrd1/4', 'Bmp1/4&3', '2ndFr3/4', 'Bmp1', 'RnOn', 'EP', 'Chl&Crd1/4', 'Bmp3', 'Crd1&3/4', 'BdCrd1/4', 'EP', '2ndFr2', 'BdCrd1/2', 'Crd3', 'MsdBrk', 'Bmp1/4', 'Crd3', 'RnOn', 'Crd1/4&1/2', 'Bmp3', 'Crd3', 'LdRnIn', 'Crd1&4', 'CrdRnUp&1/4&3', 'Bmp1', 'MsdBrk', 'Crd1/4', 'Bmp3', 'ALd', 'Mid', 'W', 'MsdBrk', 'Stmb&BdCrd2', 'CrdRnUp&1/4', 'Ckd&StoppedSough', 'EP', 'LdRnUp', 'Mid', 'EP', 'LdRnUp', 'Mid', 'W', 'Disp', '1', 'Ld2', '1/2', 'Crd1/2', 'W', 'W1/4', '2ndFr4', 'EP', 'SnLd', 'RnIn', 'EP', '2ndFr2', 'Ld3/4', 'MsdBrk', '2ndFr1/2', 'RnOn', 'Crd1/2', 'Mid', 'W', 'MsdBrk', 'W', 'W', 'RnOn', 'MsdBrk', 'CrdRnUp&4', 'Bmp1&1/4', '2ndFr2', 'Bmp1/4', 'W', 'EvCh', 'Mid', 'W', 'EP', 'Ld3', 'W', 'EP', 'LdRnUp', 'MsdBrk', 'Crd1/2', 'Bmp3', 'Crd1/4&2&1/2', 'Bmp1', 'BdCrd1/4', 'Crd4', 'W1/4', 'EP', 'Disp', 'Blk1/4', 'BmpRnUp', 'Crd1/4&3', 'Bmp1/4', '2ndFr2', 'RnOn', 'EP', '2ndFr1', '4', 'Crd1/4', 'Mid', 'W', 'Bmp1', 'Crd1/4&3/4', 'LeftStt', 'EP', 'Disp', '1/4', 'Bmp&Ld1/4', 'WStt', 'MsdBrk', 'Blk1', '(ReQul)', '2ndFr1/4', '1/2', 'Crd3', 'EP', 'Ld3', 'Crd&W1/4', 'Crd2', 'RnOn', 'Mid', 'W', 'LdRnIn', 'W', 'Crd1/2', 'EP', 'Disp', 'Bmp1/4', 'Crd3/4', 'EP', 'SnLd', '1/4', 'WRnUp', 'Crd1/4', 'MsdBrk', 'Crd2', 'Bmp3', 'W', 'CghtMuzzle', 'Stt', 'EP', 'SnLd', 'W1/4', 'CmAgn', 'Crd3/4', 'RnOn', 'W', 'EvCh', 'MsdBrk', 'BmpStt&3', 'Bmp1/4', '2ndFr2', '4', 'Crd1&3/4', 'Crd1&1/4', 'Bmp1/4', 'Crd3', 'EP', 'Disp', 'Ld1/4', 'Disp', 'Bmp1', 'RnOn', 'BmpStt', 'Crd1/4&3', 'SAw', 'Blk1/4', 'Crd1/2&3', 'EP', 'Ld1', 'Mid', 'W', 'MsdBrk', 'Bmp1', 'RnOn', 'BmpStt&1', 'Crd1/2', 'Crd1&2&1/2&3', 'EP', 'SnLd', 'Bmp1/4', 'EP', 'Disp', 'Bmp1/4', 'CrdStt&2', 'EP', 'Ld3/4', 'BmpRnUp&1', 'Crd1/4&1/2&3', 'Crd1&3', 'Bmp1/4', '2ndFr2', 'Bmp1&1/4', 'Crd ...

# %%
print("No. of different remarks/comments = ",len(set(new_vals)))
# Out:
# No. of different remarks/comments =  2675

# %%
val_counts = []
for val in set(new_vals):
    c = 0
    for val_a in new_vals:
        if val_a == val:
            c+=1
    val_counts.append((val,c))

# %%
val_counts = sorted(val_counts, key=lambda x: x[1],reverse=True)

# %%
print(val_counts)
# Out:
# [('EP', 5045), ('MsdBrk', 2457), ('Mid', 1958), ('RnOn', 1644), ('SnLd', 1363), ('Rls', 1358), ('SAw', 1344), ('Bmp1', 1124), ('Crd1', 1083), ('W', 1058), ('Ld', 1057), ('Disp', 1054), ('QAw', 1044), ('Crd1/4', 945), ('Crd3', 914), ('Bmp1/4', 808), ('Crd2', 556), ('BmpRnUp', 538), ('1', 508), ('2ndFr1', 498), ('3', 470), ('Ld1', 457), ('2', 457), ('Bmp3', 454), ('RnIn', 454), ('1/2', 434), ('4', 422), ('2ndFr2', 386), ('Bmp2', 377), ('NrLn', 376), ('Crd4', 372), ('Ld2', 366), ('Crd1/2', 351), ('(ReQul)', 340), ('BmpStt', 339), ('Crd3/4', 316), ('Ld3', 300), ('(HT)', 285), ('LdRnUp', 279), ('2ndFr1/4', 270), ('Ld4', 257), ('3/4', 257), ('1/4', 256), ('Bmp4', 255), ('LdNrLn', 255), ('Ld1/2', 247), ('Ld1/4', 246), ('CrdRnUp', 242), ('W2', 231), ('LdRnIn', 226), ('Crd5', 223), ('W1/4', 221), ('Blk1', 216), ('Fcd', 215), ('CmAgn', 212), ('Bmp1/2', 212), ('BmpRnIn', 199), ('Ckd3', 172), ('Ld3/4', 163), ('ALd', 159), ('BdCrd1/4', 158), ('BdCrd1', 156), ('CrdRnIn', 155), ('Chl3', 143), ('MidRnUp', 139), ('Ckd1', 137), ('2ndFr1/2', 137), ('Crd1/4&3', 131), ('W3/4', 128), ('5', 127), ('Chl2', 123), ('Blk1/4', 123), ('BdCrd3', 123), ('Bmp&Ld1', 120), ('Crd&W1/4', 118), ('Bmp5', 116), ('CrdStt', 114), ('VSAw', 114), ('W4', 114), ('Chl1', 113), ('Bmp3/4', 109), ('Bmp1&1/4', 104), ('Bmp&Ld1/4', 103), ('6', 103), ('Crd1&2', 101), ('Crd1&1/4', 100), ('EvCh', 99), ('StmbStt', 97), ('Crd1&3', 96), ('Blk3', 96), ('BmpRnUp&1', 93), ('Chl&Crd3', 93), ('Crd2&3', 92), ('', 91), ('Crd3B', 90), ('BdCrd2', 88), ('WRnUp', 88), ('Crd1/4&2', 87), ('Chl&Crd1/4', 87), ('Chl&Crd1', 86), ('Crd6', 84), ('Ld5', 83), ('Chl1/2', 81), ('Crd1B', 79), ('2ndFr3', 78), ('Blk2', 78), ('RlsRnUp', 78), ('Bmp1&3', 76), ('Bmp1B', 76), ('ChlRnIn', 74), ('FnWll', 73), ('2ndFr4', 71), ('BmpRls3', 68), ('BmpRls1', 68), ('Crd3&4', 67), ('Fdd', 67), ('CmAgnNrLn', 66), ('BmpRnUp&1/4', 66), ('Bmp1H', 65), ('Ld6', 62), ('EvAw', 62), ('Crd1&1/2', 61), ('Chl1/4', 59), ('Chl', 59), ('Bmp6', 56), ('Bmp1&2', 55), ('Ckd&Crd1', 54), ('Ckd2', 53), ('Crd1/4&4', 53), ('Bmp&Ld3', 53), ('Ck1', 53), ('StrFn', 53), ('Crd1&4', 52), ('Crd RnUp', 52), ('Bmp1/4&3', 52), ('W1/4&3/4', 52), ('CrdRnUp&1/4', 51), ('ClrRn', 51), ('BmpStt&1', 51), ('Ckd1/4', 50), ('Chl4', 47), ('2ndFr3/4', 47), ('HldOn', 47), ('Chl&Bmp1', 46), ('W1/2', 45), ('FAw', 45), ('Ck3', 45), ('Crd', 45), ('Crd&Ld1', 44), ('CmAgn1/2', 44), ('Crd1&5', 44), ('CrdNrLn', 43), ('Crd1/4&3/4', 43), ('BmpStt&RnUp', 42), ('CmAgn3', 42), ('VQAw', 42), ('BdBmp1', 41), ('Crd1/2&3', 41), ('Chl3/4', 40), ('Crd1&3/4', 39), ('BdBlk1', 39), ('CmAgnRnIn', 39), ('ChlFr2', 39), ('Chl&Bmp1/4', 38), ('BdBlk1/4', 38), ('Crd2H', 38), ('Crd2&4', 38), ('2H', 38), ('Crd1H', 37), ('Mid&BmpRnUp', 37), ('Bmp1/4&2', 37), ('LckdEP', 37), ('Crd1/4&1/2', 37), ('Crd&Ld1/4', 37), ('CrdRnUp&2', 36), ('VW2', 36), ('Bmp&W1/4', 36), ('Crd&Stmb1/4', 36), ('Crd3&RnIn', 35), ('ChlFr3', 35), ('BdCrd1/2', 34), ('Bmp&Ld2', 34), ('W1', 34), ('BmpNrLn', 34), ('CrdRnUp&1', 34), ('B', 34), ('Chl&Crd5', 34), ('VW', 33), ('BdCrd3/4', 32), ('CrdRnUp&3', 32), ('Crd2&1/2', 32), ('Crd&Fell1/4', 32), ('BmpStt&1/4', 32), ('Blk1/2', 32), ('Bmp2H', 31), ('NvrShwd', 31), ('Blk3/4', 31), ('Bmp&Ld4', 31), ('Ld2B', 30), ('Bmp&LdRnUp', 30), ('Crd2B', 30), ('Bmp1&4', 30), ('Hit1H', 29), ('Mid&Crd1', 29), ('1B', 29), ('Ld1B', 29), ('CmAgn4', 29), ('Ld2H', 29), ('MidStt', 28), ('Bmp3B', 28), ('BdCrd4', 28), ('CmAgn3/4', 28), ('Stt', 28), ('MvdOff&Crd1/4', 28), ('Ck2', 27), ('ChlFr4', 27), ('Crd3&3/4', 27), ('Disqualified', 27), ('Mid&BmpStt', 27), ('Bmp1/4&4', 27), ('Hit2H', 27), ('StydOn', 27), ('Ckd&Crd3', 26), ('Chl&Crd2', 26), ('HitRls3', 26), ('Hit5H', 26), ('Crd1/2&5', 26), ('W&Crd1/4', 25), ('Crd1/2&4', 25), ('Crd1&6', 25), ('Crd2&5', 25), ('Crd&W1', 25), ('Blk4', 25), ('CkdSough', 24), ('HitRls1', 24), ('DispLd', 24), ('CkdFr2', 24), ('Chl5', 23), ('Bmp2&3', 23), ('CrdStt&1/4', 23), ('Crd&Fell3', 23), ('Stmb1/4', 23), ('Crd1/4&2&3', 23), ('Crd2&3/4', 23), ('Rls&BmpStt', 23), ('Slipped', 23), ...

# %% [markdown]
# #### New column Wide
# Wide Run denoted by W in remarks

# %%
rems = []
def wide_run(field_value): # This will give the expected number of opponents, generally 6 except for trials
    try:
        if "W" in field_value:
            rems.append(field_value)
            return 1
        else:
            return 0
    except:
        return 0

# %%
df["Wide"] = df["Remarks"].apply(wide_run)

# %%
print(set(rems))
# Out:
# {'QAw,Ld-W2,W4', 'EvCh,Mid-W', 'CrdStt&1&1/4&3,FnWll', 'EP,W,SnLd-4,(HT)', 'EP,SnLd-3,Mid-W', 'W,Ld1-4', 'Crd1&3/4,Mid-W', 'SAw,Bmp3,Crd1/2,FnWll', 'EP,Chl&W1/4,W3/4', 'Crd1/4,W2', 'EP,Bmp1,Ld3,VW4', 'Crd3B,W3/4', 'MsdBrk,Mid-W,RnOn', 'Mid-W,Outp', 'EP,SnLd,Crd1,Mid-W', 'CrdRnUp,Crd&W1/4', 'MsdBrk,W,Crd3/4', 'WStt,Crd2H', 'QAw,Ld-1,W', 'EP,SnLd-W1', 'SAw,W&Blk1/4BdBmp2', 'EP,Disp-W2,ChlFr3', 'W,VSAw,Crd3', 'WRnUp,Bmp1', 'W&Crd1/4,Crd3/4', 'Crd1,Ckd&W1/4', 'EP,Mid-W,Blk1/4,Ld-3/4', 'Bmp1/4,W3/4,LdNrLn', 'MsdBrk,Ld3/4,W', 'SnLd-W4,Bmp1/4,CmAgnNrLn', 'MsdBrk,WRnUp,RnOn', 'Crd1,FcdW2', 'EP,SnLd-1/2,W2,Crd3', 'SAw,Mid-W,VW2', 'SAw,W,Ld3', 'Mid-W,Bmp1,ChlFr3/4', 'Chl3-W4', 'Bmp3/4,W', 'SAw,Crd&W1/4,Crd4', 'W&BmpRnUp,W4', 'SAw,W,CrdRnIn,(HT)', 'Bmp1/2,Crd3/4,W', 'CrdRnUp&1,Mid-W', 'MsdBrk,EP,W1/4,BdCrd3', 'W&Crd1/4', 'SAw,Crd4,FnWll', 'SnLd,WnWll', 'EP,Ld1-2,W', 'Bmp1,Chl&W&Crd4', 'MsdBrk,Crd&Stmb1/4,W2', 'EP,SnLd-2,W1/4&3/4', 'Ld1/4-W4,CmAgn', 'Crd1/4,Ld4,Mid-W', 'EP,Ld1-W2,Bmp3', 'Ld-Bmp3,Ld4-NrLn,Waited', 'W,LdNrLn', 'WRnUp,EvCh', 'W1/4,Mid', 'Mid-W,JmpWll', 'W,Crd2,RnOn', 'W,Ld-3', 'Ld1-VW2', 'Outp,FnWll', 'Crd&CkdW2,Stopped3', 'MsdBrk,EP,Bmp&W1/4,W3/4', 'CrdW1', 'VW,BndsCkdFr3', 'Rls-Mid,WRnIn', 'EP,W,ALd', 'W&BlkRnUp', 'Rls&BmpStt,Crd&W1/4,Crd2', 'VSAw,Crd1,VW2,Fdd', 'BmpStt&RnUp,Crd&W1/4', 'W&CrdStt,Crd1/4&2', 'Mid,Ld-BmpW1', 'MsdBrk,WStt,RnOn', 'W1/4,2ndFr2,Mid', 'Ld1,W', 'FAw,FnWll', 'MsdBrk,Bmp1,W1/4,Crd3', 'AW,HandyMid', 'MsdBrk,W&Crd1/4', 'BmpStt,WRnUp', 'SnLd-W1/4,Crd3&NrLn', 'EP,Disp-Bmp1/4,VW', 'W,Ld1/2', 'BmpRnUp,W1/4&3/4', 'BmpStt&4,W', 'Disp-1,W1/4,RnOn', 'CrdStt,Crd&W&Stmb1/4', 'BlkRnUp,FnWll', 'W,EvCh,(HT)', 'SAw,Mid-W,Crd3', 'Ld-Crd1,CmAgn3,Mid-W', 'MsdBrk,Crd&Stmb1/4,W3/4', '(R3)Â\xa0Mid-W,ClrRn', 'Mid-W3/4', 'Bmp1,Bmp&W1/4,W3/4', 'VSAw,VW', 'W2,Mid', 'W&CrdRnUp,Crd3B&4B', 'CrdRnUp,W2,Ckd3', 'EP,SnLd-5,Mid-W', 'Crd&W1,Crd3&5', 'EP,2ndFr1-W1/4,RnOn', 'EP,SnLd-W1/4,Crd2,W3/4', 'EP,W,Ld1-3/4', 'EP,Ld1,Mid-W', 'EP,SnLd-1/2,W3/4', 'BmpRnUp,BdCrd&W1/4', 'EP,Crd&W1/4,W3/4', 'W&Crd&Ld1/2-4,Crd5', 'LckdEP,W', 'Mid-W,Ld6', 'SnLd-W&Crd1/4,RlsRnUp', 'EP,2ndFr1-W1/4,Crd3', 'MidRnUp,Mid-W', 'CutIn1,W', 'W,Ld-2,CmAgnRnIn', 'EP,Disp-2,W', 'MsdBrk,CrdRnUp,W', 'QAw,VW2', 'Crd1,Crd&W1/4', 'W,Ld-Crd1', 'W,RnOn,(HT)', 'Mid-W2&4', 'EP,SnLd-W2,W3/4', '2ndFr1,W3/4,Mid', 'UpWithTrps,Crd2&3', 'LdRnUp-4,Mid-W', 'EP,SnLd-Bmp1/4,W3/4', 'Mid-W,MidRnIn', 'EP,2ndFr1-5,W2', 'Disp-1/4,W2,Crd3', 'MsdBrk,Crd1,W1/4', 'Mid-Rls,W2', 'MidStt,W1/4&3/4', 'Bmp1/4,W2,Crd3', 'BmpStt,Crd&W1/4,Crd3', 'Ld1/2-BmpRnIn,W', 'VW1&2', 'Crd2, Wide', 'Bmp&LdRnUp,Mid-W', 'QAw,ALd,VW2', 'QAw,Ld-1,Mid-W', 'W,Bmp1,Bmp&KO2', 'EP,LdRnUp-W2,CmAgn', 'W&BmpStt,Crd3B', 'EP,W,RnOnWll', 'SAw,Ld3,Mid-W', 'MsdBrk,W1/4,Crd4', 'EP,Disp-Bmp&Ld1/4,W4', 'StmbSltStt,Mid-W,Ld3-4', 'Disp-Ld2,Mid-W', 'WBends,NvrShwd', 'W,ALd,(HT)', 'MsdBrk,Crd1,W&Bmp2', 'VSAw,FcdVW&StmbRnUp', 'Bmp1,W2,Crd3/4', 'W,Bmp1/4,RnOn', 'CrdStt,RnOnWll', 'EP,W1/4,Crd3,RnOn', 'W2,BmpRnIn', 'W,SnLd', 'Crd&WRnUp,W4', 'W&CrdRnUp,Chl2,LdRnIn', 'W,EP,Crd2', 'W,Bmp1/2', 'EP,W,SnLd,HldOn', 'W1/4,2ndFr3', 'Crd&W1,RnOn', 'MsdBrk,W&Bmp2&4,RnOn', 'SAw,Crd2&3,W', 'BmpRnUp,LdNrLn,W', 'SAw,CrdStt&2,WRnUp', 'SAw,Crd1&1/4,W4', 'Rls&CrdStt,W1/4', '2ndFr3,W', 'Crd1&NrLn,W4', 'EP,W&Crd1/4', 'Crd&WRnUp,Crd3', 'Crd&CkdW1', 'EP,LdRnUp-W2,W3/4', 'QAw,W,Ld-1,CmAgn', 'SAw,W&Stmb1/4,W3/4', '(R3)Â\xa0Mid-W,Ld3', 'WRnUp,LdRnIn', 'MsdBrk,W1/4,Crd2&3', 'Crd1,W4', 'MsdBrk,W,Slipped3/4', 'EP,SnLd-W1/4,CmAgn3', 'Ld-Blk1,WRnUp', 'EP,W,Bmp2', 'W2&3/4', 'MsdBrk,EP,Bmp1/4,W3/4', 'W,Crd1', 'MsdBrk,BmpRnUp,W', 'FcdW1,RnOn,Mid-W', 'W,Ld1', 'MsdBrk,W&CrdRnUp,Crd1/4', 'SnLd,FnWll', 'W2,Bmp3', 'W,FnWll', "EP,Ld-1/2,VW,Thr'Out", 'EP,Bmp1/4,W', 'Disp-W1/4,Chl3-4', 'W,BdCrd1/4', 'SnLd-W1/4,Chl3-W3/4', 'Blk&FcdW1/4', '2ndFr1/2,Mid-W', 'CrdStt,BmpRnUp,Crd&W1/4', 'WRnUp,Disp-1,Crd2', 'Bmp1,Ld2,W4', 'EP,Ld3,Mid-W', 'MsdBrk,W,Bmp4', 'QAw,Ld-1,W2', 'EP,LdRnUp,W', 'WStt,2ndFr2-3/4', 'EP,SnLd-NrLn,W2&4', 'CrdStt,W2H', 'SnLd-W3/4,MidRnUp', 'Bmp1/4,W', 'W&CrdStt,Blk1/4,Bm ...

# %%
# Approximately 10% of runners go wide
print("Wide runner rate")
print(round(df["Wide"].sum()/len(df),2)*100,"%")
# Out:
# Wide runner rate
# 10.0 %

# %% [markdown]
# ### EXPORT DATA

# %%
df.to_csv("greyhound_database_cleaned.csv", index=False, encoding='utf-8-sig')
